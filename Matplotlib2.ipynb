# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
from matplotlib import style

# %%
x=[16,8,10]
y=[8,16,6]

x2=[8,15,11]
y2=[6,15,7]


x3=[7,8,9]
y3=[1,5,9]

plt.plot(x,y,'r',linewidth=10)
plt.plot(x2,y2,'g',linewidth=10)
plt.plot(x3,y3,'b',linewidth=10)


plt.title("info table")

plt.xlabel("data1")
plt.ylabel("data2")



style.use('ggplot')
plt.grid(True,color='c')

# %%
x=np.arange(1,10,2)
y=np.sin(x)


print(x,y)

#plt.plot(x,y)
ax=plt.axes()
ax.fill_between([1,2,3],[1,2,5],facecolor="red")
# Out:
# [1 3 5 7 9] [ 0.84147098  0.14112001 -0.95892427  0.6569866   0.41211849]

# %%
players=['Sachin','Dhoni','Ganguly','Rahul','Sehwag']
runsinmatch=[123,51,27,88,99]
average=[89,90,45,80,100]


plt.barh(players,average,color='k')
# Out:
# <BarContainer object of 5 artists>

# %%
players=['Sachin','Dhoni','Ganguly','Rahul','Sehwag']
runsinmatch=[123,51,27,88,99]
average=[89,90,45,80,100]


plt.pie(runsinmatch,labels=players)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe1ebeb2390>,
# ...
#  [Text(0.5981066201197109, 0.9231838771171083, 'Sachin'),
#   Text(-0.8146723049572145, 0.7391272120113692, 'Dhoni'),
#   Text(-1.0939118560444188, 0.11557184434564831, 'Ganguly'),
#   Text(-0.7456992605130599, -0.8086609999686369, 'Rahul'),
#   Text(0.7651201853368715, -0.7903107629218216, 'Sehwag')])

# %%
players=['Sachin','Dhoni','Ganguly','Rahul','Sehwag']
runsinmatch=[123,51,27,88,99]
average=[89,90,45,80,100]


raja=[1,2,3,4,5]

plt.pie(runsinmatch,explode=raja,labels=players)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe1eb8a3b38>,
# ...
#  [Text(1.1418399111376298, 1.7624419472235702, 'Sachin'),
#   Text(-2.2958946776066953, 2.0829948702138585, 'Dhoni'),
#   Text(-4.077307827074652, 0.43076778347014366, 'Ganguly'),
#   Text(-3.457332935106005, -3.7492464544000437, 'Rahul'),
#   Text(4.242939209595378, -4.382632412566465, 'Sehwag')])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])


data=[
    
    [1,2,3,5],
    [1,2,3,6],
    [1,2,3,7],
    [1,2,3,8],
    
    
]

ax.boxplot(data,'B')
np.mean([1,2,3,8])
# Out:
# 3.5
